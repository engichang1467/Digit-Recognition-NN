# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_test = tf.keras.utils.normalize(x_test, axis=1)
for test in range(len(x_test)):
    for row in range(28):
        for x in range(28):
            if x_test[test][row][x] != 0:
                x_test[test][row][x] = 1


model = tf.keras.models.load_model('numReader.model')
print(len(x_test))
predictions = model.predict(x_test[:10])

count = 0
for x in range(len(predictions)):
    guess = (np.argmax(predictions[x]))
    actual = y_test[x]
    print(f'I predict this number is {guess}')
    print(f'Number Actually Is {actual}')
    if guess != actual:
        count+=1
    plt.imshow(x_test[x], cmap=plt.cm.binary)
    plt.show()

print(f'The program got {count} wrong, out of {len(x_test)}')
print(f'{str(100 - ((count/len(x_test))*100))}% correct')
# Out:
# 10000
# I predict this number is a: 7
# Number Actually Is a:7
# I predict this number is a: 2
# Number Actually Is a:2
# I predict this number is a: 1
# Number Actually Is a:1
# I predict this number is a: 0
# Number Actually Is a:0
# I predict this number is a: 4
# Number Actually Is a:4
# I predict this number is a: 1
# Number Actually Is a:1
# I predict this number is a: 4
# Number Actually Is a:4
# I predict this number is a: 9
# Number Actually Is a:9
# I predict this number is a: 5
# Number Actually Is a:5
# I predict this number is a: 9
# Number Actually Is a:9
# The program got 0 wrong, out of 10000
# 100.0% correct
